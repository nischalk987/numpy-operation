# %% [markdown]
# # Advance operation with Business examples

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Data structure: [restaurant_id, 2021, 2022, 2023, 2024]
sales_data = np.array([
    [1, 150000, 180000, 220000, 250000],  # Paradise Biryani
    [2, 120000, 140000, 160000, 190000],  # Beijing Bites
    [3, 200000, 230000, 260000, 300000],  # Pizza Hub
    [4, 180000, 210000, 240000, 270000],  # Burger Point
    [5, 160000, 185000, 205000, 230000]   # Chai Point
])

print("=== Zomato sales analysis ===")
print("sales data shape " , np.shape(sales_data))
print("Sample data for 1st 3 restaurants:\n",sales_data[:3])
# Out:
# === Zomato sales analysis ===
# sales data shape  (5, 5)
# Sample data for 1st 3 restaurants:
#  [[     1 150000 180000 220000 250000]
#  [     2 120000 140000 160000 190000]
#  [     3 200000 230000 260000 300000]]

# %%
# total sales per year
print("total sales per year : ", np.sum(sales_data,axis=0))
yearly_total = np.sum(sales_data[:, 1:],axis=0)
print(yearly_total)

# minimum sales per restaurant
print("minumum sales per restaurant : ", np.min(sales_data[:,1:],axis=1))

#maximum sales per year
print("maximum sales per year : " , np.max(sales_data[:,1:],axis=0))

# Average sales per restaurants
print("Average sales per restaurants : " , np.mean(sales_data[:,1:],axis=1))
# Out:
# total sales per year :  [     15  810000  945000 1085000 1240000]
# [ 810000  945000 1085000 1240000]
# minumum sales per restaurant :  [150000 120000 200000 180000 160000]
# maximum sales per year :  [200000 230000 260000 300000]
# Average sales per restaurants :  [200000. 152500. 247500. 225000. 195000.]

# %%
cumsum = np.cumsum(sales_data[:,1:],axis=1)
print("Cumulative sum :\n " , cumsum)

plt.figure(figsize=(10,6))
plt.plot(np.mean(cumsum,axis=0))
plt.title("Average cumulative sales accross all restaurant")
plt.xlabel("Years")
plt.ylabel("Sales")
plt.grid(True)
plt.show()
# Out:
# Cumulative sum :
#   [[150000 330000 550000 800000]
#  [120000 260000 420000 610000]
#  [200000 430000 690000 990000]
#  [180000 390000 630000 900000]
#  [160000 345000 550000 780000]]

# %%
vector1 = np.array([1,2,3,4,5,6,7,8])
vector2 = np.array([1,2,3,4,5,6,7,8])

print("Vector addition : " , vector1 + vector2)
print("vector multiplication : " , vector1 * vector2)
print("Dot product :" , np.dot(vector1 , vector2))
print("Angle : " , np.arccos(np.dot(vector1 , vector2) / (np.linalg.norm(vector1) * np.linalg.norm(vector2))))
# Out:
# Vector addition :  [ 2  4  6  8 10 12 14 16]
# vector multiplication :  [ 1  4  9 16 25 36 49 64]
# Dot product : 204
# Angle :  1.4901161193847656e-08

# %% [markdown]
# # Vector operation

# %%
restaurants_types = np.array(['Briyan','chiness','pizza','burger','cafe'])
vectorized_upper = np.vectorize(str.upper)
print("Upper case array : " , vectorized_upper(restaurants_types))
# Out:
# Upper case array :  ['BRIYAN' 'CHINESS' 'PIZZA' 'BURGER' 'CAFE']

# %%
monthly_avg = sales_data[:,1:] / 12
print(monthly_avg)
# Out:
# [[12500.         15000.         18333.33333333 20833.33333333]
#  [10000.         11666.66666667 13333.33333333 15833.33333333]
#  [16666.66666667 19166.66666667 21666.66666667 25000.        ]
#  [15000.         17500.         20000.         22500.        ]
#  [13333.33333333 15416.66666667 17083.33333333 19166.66666667]]
